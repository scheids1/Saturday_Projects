# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data Source
#
# https://www.lendingclub.com/info/download-data.action (Loan data 2016 Q1)

# %%
df = pd.read_csv("LoanStats_2016Q1.csv", skiprows=1, skipfooter=2, engine='python')
print(df.shape)
df.head()
# Out:
# (133887, 145)
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      34000        34000          34000.0   36 months
# 1 NaN        NaN       5900         5900           5900.0   36 months
# 2 NaN        NaN       7500         7500           7500.0   36 months
# 3 NaN        NaN      35000        35000          34975.0   36 months
# 4 NaN        NaN      28000        28000          28000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0    9.75%      1093.10     B        B3       ...
# 1   11.99%       195.94     C        C1       ...
# 2   12.99%       252.67     C        C2       ...
# 3   19.53%      1292.36     D        D5       ...
# 4   13.67%       952.50     C        C3       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Dropping all columns that are all NaN
df = df.dropna(axis=1, how='all')
print(df.shape)
df.head()
# Out:
# (133887, 131)
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0      34000        34000          34000.0   36 months    9.75%      1093.10
# 1       5900         5900           5900.0   36 months   11.99%       195.94
# 2       7500         7500           7500.0   36 months   12.99%       252.67
# 3      35000        35000          34975.0   36 months   19.53%      1292.36
# 4      28000        28000          28000.0   36 months   13.67%       952.50
#
#   grade sub_grade         emp_title emp_length       ...        \
# 0     B        B3         President  10+ years       ...
# 1     C        C1        Bus Driver    3 years       ...
# 2     C        C2  Registered Nurse   < 1 year       ...
# 3     D        D5   General Manager  10+ years       ...
# 4     C        C3  Terminal Manager    8 years       ...
#
#   hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 0                            NaN                           NaN
# ...

# %%
list(df.columns)
# Out:
# ['loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
# ...

# %%
df.dtypes
# Out:
# loan_amnt                                       int64
# funded_amnt                                     int64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                       object
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# pymnt_plan                                     object
# desc                                           object
# ...

# %%
# Convert interest rate to a float -- not a string 
df['int_rate'] = df['int_rate'].str.strip('%').astype(float)

# Convert term to an int -- not a string 
df['term'] = df['term'].str.strip('months').astype(int)

# %%
# df.corr().abs().unstack().sort_values(ascending=False)

# %% [markdown]
# ## Plotting & Styles
#
# As this dataset has a wealth of variables, I decided to do some fun plotting and play around with features.
#
# A useful guide to matplotlib: https://realpython.com/python-matplotlib-guide/

# %%
# Looking at the list of available styles
plt.style.available
# Out:
# ['_classic_test',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10']

# %% [markdown]
# **Let's look at the same data plotted using a few different styles. Fivethirtyeight, seaborn, and ggplot all tend to be popular options. **
#
# Here, the style is set temporarily, not globally, for each cell/plot. To set it globally, call **plt.style.use("fivethirtyeight")**

# %%
fig = plt.figure(figsize=(20,16))
ax1 = plt.subplot(221)
ax1.hist(df['loan_amnt'], bins=40)
plt.title("Loan Amounts")
plt.xlabel("Loan Amount")
plt.ylabel("Frequency")
ax2 = plt.subplot(222)
ax2.hist(df['int_rate'], bins=30)
plt.title("Interest Rates")
plt.xlabel("Interest Rate")
plt.ylabel("Frequency")
ax3 = plt.subplot(223)
ax3.scatter(df['loan_amnt'], df['installment'], s=0.25)
plt.title("Loan Amount vs Installment Size")
plt.xlabel("Loan Amount")
plt.ylabel("Installment Amount")
ax4 = plt.subplot(224)
ax4.scatter(df['loan_amnt'], df['annual_inc'])
plt.title("Loan Amounts versus Annual Income")
plt.xlabel("Loan Amount")
plt.ylabel("Annual Income")
plt.show()

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(20,16))
    ax1 = plt.subplot(221)
    ax1.hist(df['loan_amnt'], bins=40)
    plt.title("Loan Amounts")
    plt.xlabel("Loan Amount")
    plt.ylabel("Frequency")
    ax2 = plt.subplot(222)
    ax2.hist(df['int_rate'], bins=30)
    plt.title("Interest Rates")
    plt.xlabel("Interest Rate")
    plt.ylabel("Frequency")
    ax3 = plt.subplot(223)
    ax3.scatter(df['loan_amnt'], df['installment'], s=0.25)
    plt.title("Loan Amount vs Installment Size")
    plt.xlabel("Loan Amount")
    plt.ylabel("Installment Amount")
    ax4 = plt.subplot(224)
    ax4.scatter(df['loan_amnt'], df['annual_inc'])
    plt.title("Loan Amounts versus Annual Income")
    plt.xlabel("Loan Amount")
    plt.ylabel("Annual Income")
    plt.show()

# %%
with plt.style.context('seaborn'):
    fig = plt.figure(figsize=(20,16))
    ax1 = plt.subplot(221)
    ax1.hist(df['loan_amnt'], bins=40)
    plt.title("Loan Amounts")
    plt.xlabel("Loan Amount")
    plt.ylabel("Frequency")
    ax2 = plt.subplot(222)
    ax2.hist(df['int_rate'], bins=30)
    plt.title("Interest Rates")
    plt.xlabel("Interest Rate")
    plt.ylabel("Frequency")
    ax3 = plt.subplot(223)
    ax3.scatter(df['loan_amnt'], df['installment'], s=0.25)
    plt.title("Loan Amount vs Installment Size")
    plt.xlabel("Loan Amount")
    plt.ylabel("Installment Amount")
    ax4 = plt.subplot(224)
    ax4.scatter(df['loan_amnt'], df['annual_inc'])
    plt.title("Loan Amounts versus Annual Income")
    plt.xlabel("Loan Amount")
    plt.ylabel("Annual Income")
    plt.show()

# %%
with plt.style.context('ggplot'):
    fig = plt.figure(figsize=(20,16))
    ax1 = plt.subplot(221)
    ax1.hist(df['loan_amnt'], bins=40)
    plt.title("Loan Amounts")
    plt.xlabel("Loan Amount")
    plt.ylabel("Frequency")
    ax2 = plt.subplot(222)
    ax2.hist(df['int_rate'], bins=30)
    plt.title("Interest Rates")
    plt.xlabel("Interest Rate")
    plt.ylabel("Frequency")
    ax3 = plt.subplot(223)
    ax3.scatter(df['loan_amnt'], df['installment'], s=0.25)
    plt.title("Loan Amount vs Installment Size")
    plt.xlabel("Loan Amount")
    plt.ylabel("Installment Amount")
    ax4 = plt.subplot(224)
    ax4.scatter(df['loan_amnt'], df['annual_inc'])
    plt.title("Loan Amounts versus Annual Income")
    plt.xlabel("Loan Amount")
    plt.ylabel("Annual Income")
    plt.show()

# %%
with plt.style.context('grayscale'):
    fig = plt.figure(figsize=(20,16))
    ax1 = plt.subplot(221)
    ax1.hist(df['loan_amnt'], bins=40)
    plt.title("Loan Amounts")
    plt.xlabel("Loan Amount")
    plt.ylabel("Frequency")
    ax2 = plt.subplot(222)
    ax2.hist(df['int_rate'], bins=30)
    plt.title("Interest Rates")
    plt.xlabel("Interest Rate")
    plt.ylabel("Frequency")
    ax3 = plt.subplot(223)
    ax3.scatter(df['loan_amnt'], df['installment'], s=0.25)
    plt.title("Loan Amount vs Installment Size")
    plt.xlabel("Loan Amount")
    plt.ylabel("Installment Amount")
    ax4 = plt.subplot(224)
    ax4.scatter(df['loan_amnt'], df['annual_inc'])
    plt.title("Loan Amounts versus Annual Income")
    plt.xlabel("Loan Amount")
    plt.ylabel("Annual Income")
    plt.show()
